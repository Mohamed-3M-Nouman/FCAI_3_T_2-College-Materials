# %% [markdown]
# ![image.png](attachment:07919b63-32af-4838-8bc1-9922f1adb9df.png)

# %% [markdown]
# ![image.png](attachment:aeaac2af-98fe-46d8-8e5f-844a7d57e831.png)

# %% [markdown]
# # What is SciPy?
# SciPy is a free and open-source Python library used for scientific computing and technical computing. It is a collection of
# mathematical algorithms and convenience functions built on the NumPy extension of Python. It adds significant power to the interactive Python session by providing the user with high-level commands and classes for manipulating and visualizing data. As mentioned earlier, SciPy builds on NumPy and therefore if you import SciPy, there is no need to import NumPy.

# %% [markdown]
# # Sub packages in SciPy
# Many dedicated software tools are necessary for Python scientific computing,
# and SciPy is one such tool or library offering many Python modules that we can work with in order to perform complex operations.
#
# The following table shows some of the modules or sub-packages that can be used for computing:

# %% [markdown]
# ![image.png](attachment:ae2cebbc-2b18-4005-b14e-8b57d69f335e.png)

# %%
from scipy.io import arff
data = arff.loadarff('datasetsweather.arff')
print(data)
# Out:
# (array([(b'sunny', 85., 85., b'FALSE', b'no'),
#        (b'sunny', 80., 90., b'TRUE', b'no'),
#        (b'overcast', 83., 86., b'FALSE', b'yes'),
#        (b'rainy', 70., 96., b'FALSE', b'yes'),
#        (b'rainy', 68., 80., b'FALSE', b'yes'),
#        (b'rainy', 65., 70., b'TRUE', b'no'),
#        (b'overcast', 64., 65., b'TRUE', b'yes'),
#        (b'sunny', 72., 95., b'FALSE', b'no'),
#        (b'sunny', 69., 70., b'FALSE', b'yes'),
#        (b'rainy', 75., 80., b'FALSE', b'yes'),
#        (b'sunny', 75., 70., b'TRUE', b'yes'),
#        (b'overcast', 72., 90., b'TRUE', b'yes'),
#        (b'overcast', 81., 75., b'FALSE', b'yes'),
#        (b'rainy', 71., 91., b'TRUE', b'no')],
#       dtype=[('outlook', 'S8'), ('temperature', '<f8'), ('humidity', '<f8'), ('windy', 'S5'), ('play', 'S3')]), Dataset: weather
# 	outlook's type is nominal, range is ('sunny', 'overcast', 'rainy')
# 	temperature's type is numeric
# 	humidity's type is numeric
# ...

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
data[0]['outlook']
# Out:
# array([b'sunny', b'sunny', b'overcast', b'rainy', b'rainy', b'rainy',
#        b'overcast', b'sunny', b'sunny', b'rainy', b'sunny', b'overcast',
#        b'overcast', b'rainy'], dtype='|S8')
